# %%
from datetime import datetime
from operator import itemgetter
from os import path

from astropy.table import Table
from skynet.api.v20 import errors
from skynet.api.v20.methods import download, groups, obs

# for turning into command line program:
    # -b begtime
    # -e endtime
    # -d data_directory [Data]
    # -o
    # -i

# %%
# define parameters to control the code below

data_directory = "Data"
start_time = "2022-09-06T00:00:00" # only download files after this time
# start_time = "2024-08-15 00:00:00" # only download files after this time
observation_criteria = {"groupId": groups.get("Majewski Research Group")["id"]}
exposure_criteria = observation_criteria

# scope_id = scopes.query(include="*", **{"name": "RRRT"})[0]["id"]

observation_criteria
# Out:
# {'groupId': 816}

# %%
# retrieve list of observations happening after start_time and meeting observation_criteria
# write to csv just in case it's useful

observation_fields = {
    "id": "Observation ID",
    "state": "Observation state",
    "priority": "Priority",
    "name": "Target Name",
    "user.username": "Username",
    "group.name": "Group",
    "raHours": "RA",
    "decDegs": "Dec",
    "currentTelescope.name": "Telescope",
    "teleOwner.name": "Scope Owner",
    "timeIn": "Submitted",
}

observation_results = obs.query(include=",".join(observation_fields.keys()), after=start_time, **observation_criteria)

observations = Table()
for field, col_name in observation_fields.items():
    field_parts = field.split(".")
    match len(field_parts):
        case 1:
            observations[col_name] = list(map(itemgetter(field), observation_results))
        case 2:
            field_dicts = list(map(itemgetter(field_parts[0]), observation_results))
            observations[col_name] = [field_dict[field_parts[1]] if field_dict is not None else "" for field_dict in field_dicts]
observations.write("skynet_observations.csv", overwrite=True)

observations
# Out:
# <Table length=99>
# Observation ID Observation state Priority ... Scope Owner      Submitted
#     int32             str9        int32   ...     str3           str19
# -------------- ----------------- -------- ... ----------- -------------------
#       10067782          canceled        7 ...         UVA 2023-09-19T03:41:44
#       10067789          canceled        7 ...         UVA 2023-09-19T03:58:54
#       10277972          canceled        1 ...         UVA 2023-11-09T22:20:21
#       10279223         completed        1 ...         UVA 2023-11-10T16:11:01
#       10286988         completed        5 ...         UVA 2023-11-11T18:49:29
#       10287062         completed        5 ...         UVA 2023-11-12T04:57:35
#       10287063         completed        5 ...         UVA 2023-11-12T05:04:17
#       10287064         completed        5 ...         UVA 2023-11-12T05:27:06
#       10291478         completed        5 ...         UVA 2023-11-13T01:53:33
#       10291510         completed        7 ...         UVA 2023-11-13T03:06:03
#            ...               ...      ... ...         ...                 ...
#       11598691          canceled        1 ...         UVA 2024-08-26T01:52:40
#       11601694          canceled        6 ...         UVA 2024-08-26T21:14:18
#       11608344          canceled        4 ...         UVA 2024-08-28T17:47:17
#       11625737         completed        1 ...         UVA 2024-09-02T22:18:36
#       11633327          canceled        4 ...         UVA 2024-09-04T23:27:06
#       11636444          canceled        3 ...         UVA 2024-09-05T21:27:37
#       11636835          canceled        1 ...         UVA 2024-09-06T00:52:37
#       11636836          canceled        3 ...         UVA 2024-09-06T00:56:21
#       11636838         completed        4 ...         UVA 2024-09-06T01:02:26
#       11636840         completed        1 ...         UVA 2024-09-06T01:06:47

# %%
# retrieve list of images happening after start_time and meeting exposure_criteria
# write to csv just in case it's useful

exposure_fields = {
    "exps.obsId": "Observation ID",
    "exps.expNum": "Exposure Num",
    "exps.imageId": "Image ID",
    "exps.obs.name": "Name",
    "exps.type": "Type",
    "exps.filterName": "Filter Name",
    "exps.timeTaken": "Time Taken",
    "exps.state": "Image State",
    "exps.expLengthUsed": "Exposure",
    "exps.binningUsed": "Binning",
    "exps.gain": "Gain",
    "exps.camera.name": "Camera",
}

exposure_results = obs.query(include=",".join(exposure_fields.keys()), after=start_time, **exposure_criteria)

exp_structs = [image for result in exposure_results for image in result["exps"]]
images = Table()
for field, col_name in exposure_fields.items():
    field_parts = field.split(".")
    match len(field_parts):
        case 2:
            images[col_name] = list(map(itemgetter(field_parts[1]), exp_structs))
        case 3:
            field_dicts = list(map(itemgetter(field_parts[1]), exp_structs))
            images[col_name] = [field_dict[field_parts[2]] if field_dict is not None else "" for field_dict in field_dicts]
images.write("skynet_images.csv", overwrite=True)

images
# Out:
# <Table length=179875>
# Observation ID Exposure Num ...   Gain                   Camera
#     int32         int32     ...  object                  str40
# -------------- ------------ ... ------- ----------------------------------------
#       10067782            0 ... 1.33183 UVA SBIG STX-16803 with FLI Filter Wheel
#       10067782            1 ... 1.33183 UVA SBIG STX-16803 with FLI Filter Wheel
#       10067782            2 ... 1.33183 UVA SBIG STX-16803 with FLI Filter Wheel
#       10067782            3 ... 1.33183 UVA SBIG STX-16803 with FLI Filter Wheel
#       10067782            4 ... 1.33183 UVA SBIG STX-16803 with FLI Filter Wheel
#       10067782            5 ... 1.33183 UVA SBIG STX-16803 with FLI Filter Wheel
#       10067782            6 ... 1.33183 UVA SBIG STX-16803 with FLI Filter Wheel
#       10067782            7 ... 1.33183 UVA SBIG STX-16803 with FLI Filter Wheel
#       10067782            8 ... 1.33183 UVA SBIG STX-16803 with FLI Filter Wheel
#       10067782            9 ... 1.33183 UVA SBIG STX-16803 with FLI Filter Wheel
#            ...          ... ...     ...                                      ...
#       11636840         1990 ... 1.30984 UVA SBIG STX-16803 with FLI Filter Wheel
#       11636840         1991 ... 1.30984 UVA SBIG STX-16803 with FLI Filter Wheel
#       11636840         1992 ... 1.30984 UVA SBIG STX-16803 with FLI Filter Wheel
#       11636840         1993 ... 1.30984 UVA SBIG STX-16803 with FLI Filter Wheel
#       11636840         1994 ... 1.30984 UVA SBIG STX-16803 with FLI Filter Wheel
#       11636840         1995 ... 1.30984 UVA SBIG STX-16803 with FLI Filter Wheel
#       11636840         1996 ... 1.30984 UVA SBIG STX-16803 with FLI Filter Wheel
#       11636840         1997 ... 1.30984 UVA SBIG STX-16803 with FLI Filter Wheel
#       11636840         1998 ... 1.30984 UVA SBIG STX-16803 with FLI Filter Wheel
#       11636840         1999 ... 1.30984 UVA SBIG STX-16803 with FLI Filter Wheel

# %%
# do the actual download of the identified files
# skip files that already exist

def download_file_part(data_directory, obs_id, target, num_parts, part_num):
    if num_parts > 1:
        filename = f"{data_directory}/{obs_id}-{target}_{part_num}.zip"
    else:
        filename = f"{data_directory}/{obs_id}-{target}.zip"
    if path.isfile(filename):
        print(f"  File {filename} already downloaded")
        return
    print(f"  Downloading part {part_num}...", end=" ")
    _, data = download.fits(**{"obs": obs_id}, total_parts=num_parts, part=part_num)
    filesize = len(data)
    duration = datetime.now() - start
    if filesize > 0:
        with open(filename, "wb") as f:
            f.write(data)
        print(f"got {filesize/1024/1024:7.1f}MB at {filesize / duration.seconds * 8 / 1024 / 1024:5.2f}Mbps saved to {filename}")

for observation in observations:
    obs_id = observation[observation_fields["id"]]
    target = observation[observation_fields["name"]].strip().replace(" ", "_")
    print(f"Downloading observation {obs_id:10d}")
    start = datetime.now()
    num_images = len(images[images["Observation ID"] == obs_id])
    num_parts = num_images // 1000 + 1
    for part_num in range(1, num_parts + 1):
        try:
            download_file_part(data_directory, obs_id, target, num_parts, part_num)
        except errors.BadRequestError:
            print(f"  skipped part {part_num}- got bad request")
            continue
print("---Downloads Complete---")
# Out:
# Downloading observation   10067782
#   File Data/10067782-TIC_269811101.zip already downloaded
# Downloading observation   10067789
#   File Data/10067789-TIC_375325607.zip already downloaded
# Downloading observation   10277972
#   Downloading part 1...   skipped part 1- got bad request
# Downloading observation   10279223
#   File Data/10279223-TIC_239872462_Ab.zip already downloaded
# Downloading observation   10286988
#   File Data/10286988-TIC_239872462_Ab.zip already downloaded
# Downloading observation   10287062
#   File Data/10287062-TIC_239872462_Ab.zip already downloaded
# Downloading observation   10287063
#   File Data/10287063-TIC_239872462_Ab.zip already downloaded
# Downloading observation   10287064
#   File Data/10287064-TIC_239872462_Ab.zip already downloaded
# Downloading observation   10291478
#   File Data/10291478-TIC_239872462_Ab.zip already downloaded
# Downloading observation   10291510
#   File Data/10291510-TIC_239872462_SHIFT_111323UTC.zip already downloaded
# Downloading observation   10291512
#   File Data/10291512-TIC_239872462_SHIFT_111323UTC.zip already downloaded
# Downloading observation   10291513
#   File Data/10291513-TIC_239872462_SHIFT_111323UTC_1.zip already downloaded
#   File Data/10291513-TIC_239872462_SHIFT_111323UTC_2.zip already downloaded
#   File Data/10291513-TIC_239872462_SHIFT_111323UTC_3.zip already downloaded
#   File Data/10291513-TIC_239872462_SHIFT_111323UTC_4.zip already downloaded
# Downloading observation   10349683
#   File Data/10349683-TIC_4707_Cal.zip already downloaded
# Downloading observation   10349685
#   File Data/10349685-TIC_4707_Cal_1.zip already downloaded
#   File Data/10349685-TIC_4707_Cal_2.zip already downloaded
#   File Data/10349685-TIC_4707_Cal_3.zip already downloaded
#   File Data/10349685-TIC_4707_Cal_4.zip already downloaded
#   File Data/10349685-TIC_4707_Cal_5.zip already downloaded
# Downloading observation   10408756
#   File Data/10408756-TIC_200094011_Ab_Cal.zip already downloaded
# Downloading observation   10408762
#   File Data/10408762-TIC_200094011_Ab_Cal_2.zip already downloaded
# Downloading observation   10408763
#   File Data/10408763-TIC_367448265_Bb_Cal.zip already downloaded
# Downloading observation   10408764
#   File Data/10408764-TIC_367448265_Bb_Cal.zip already downloaded
# Downloading observation   10408766
#   File Data/10408766-TIC_367448265_Bb_1.zip already downloaded
#   File Data/10408766-TIC_367448265_Bb_2.zip already downloaded
#   File Data/10408766-TIC_367448265_Bb_3.zip already downloaded
#   File Data/10408766-TIC_367448265_Bb_4.zip already downloaded
#   File Data/10408766-TIC_367448265_Bb_5.zip already downloaded
#   File Data/10408766-TIC_367448265_Bb_6.zip already downloaded
#   File Data/10408766-TIC_367448265_Bb_7.zip already downloaded
#   File Data/10408766-TIC_367448265_Bb_8.zip already downloaded
#   File Data/10408766-TIC_367448265_Bb_9.zip already downloaded
# Downloading observation   10447535
#   File Data/10447535-TIC_307119043_Cal.zip already downloaded
# Downloading observation   10447536
#   File Data/10447536-TIC_307119043_Bb_1.zip already downloaded
#   File Data/10447536-TIC_307119043_Bb_2.zip already downloaded
#   File Data/10447536-TIC_307119043_Bb_3.zip already downloaded
#   File Data/10447536-TIC_307119043_Bb_4.zip already downloaded
#   File Data/10447536-TIC_307119043_Bb_5.zip already downloaded
# Downloading observation   10461044
#   File Data/10461044-TIC_239872462_Ab_Cal.zip already downloaded
# Downloading observation   10461045
#   File Data/10461045-TIC_239872462_Ab_Cal_Shift.zip already downloaded
# Downloading observation   10461046
#   File Data/10461046-TIC_239872462_Ab_Cal_Shift.zip already downloaded
# Downloading observation   10461047
#   File Data/10461047-TIC_239872462_Ab_Shift_1.zip already downloaded
#   File Data/10461047-TIC_239872462_Ab_Shift_2.zip already downloaded
# Downloading observation   10466031
#   Downloading part 1...   skipped part 1- got bad request
#   Downloading part 2...   skipped part 2- got bad request
#   Downloading part 3...   skipped part 3- got bad request
#   Downloading part 4...   skipped part 4- got bad request
#   Downloading part 5...   skipped part 5- got bad request
# Downloading observation   10466032
#   File Data/10466032-TIC_4707_Cal_1.zip already downloaded
#   File Data/10466032-TIC_4707_Cal_2.zip already downloaded
#   File Data/10466032-TIC_4707_Cal_3.zip already downloaded
#   File Data/10466032-TIC_4707_Cal_4.zip already downloaded
#   File Data/10466032-TIC_4707_Cal_5.zip already downloaded
# Downloading observation   10469897
#   File Data/10469897-TIC_292318612_Bab.zip already downloaded
# Downloading observation   10469898
#   File Data/10469898-TIC_292318612_Bab_1.zip already downloaded
#   File Data/10469898-TIC_292318612_Bab_2.zip already downloaded
# Downloading observation   10474112
#   File Data/10474112-TIC_367448265_Ba.zip already downloaded
# Downloading observation   10474113
#   File Data/10474113-TIC_367448265_Ba.zip already downloaded
# Downloading observation   10474114
#   File Data/10474114-TIC_367448265_Ba.zip already downloaded
# Downloading observation   10474115
#   File Data/10474115-TIC_367448265_Ba.zip already downloaded
# Downloading observation   10474116
#   Downloading part 1...   skipped part 1- got bad request
#   Downloading part 2...   skipped part 2- got bad request
#   Downloading part 3...   skipped part 3- got bad request
#   Downloading part 4...   skipped part 4- got bad request
#   Downloading part 5...   skipped part 5- got bad request
#   Downloading part 6...   skipped part 6- got bad request
#   Downloading part 7...   skipped part 7- got bad request
#   Downloading part 8...   skipped part 8- got bad request
#   Downloading part 9...   skipped part 9- got bad request
#   Downloading part 10...   skipped part 10- got bad request
#   Downloading part 11...   skipped part 11- got bad request
# Downloading observation   10474117
#   File Data/10474117-TIC_367448265_Ba_1.zip already downloaded
#   File Data/10474117-TIC_367448265_Ba_2.zip already downloaded
#   File Data/10474117-TIC_367448265_Ba_3.zip already downloaded
#   File Data/10474117-TIC_367448265_Ba_4.zip already downloaded
#   File Data/10474117-TIC_367448265_Ba_5.zip already downloaded
#   File Data/10474117-TIC_367448265_Ba_6.zip already downloaded
#   File Data/10474117-TIC_367448265_Ba_7.zip already downloaded
#   File Data/10474117-TIC_367448265_Ba_8.zip already downloaded
#   File Data/10474117-TIC_367448265_Ba_9.zip already downloaded
#   File Data/10474117-TIC_367448265_Ba_10.zip already downloaded
#   File Data/10474117-TIC_367448265_Ba_11.zip already downloaded
# Downloading observation   10479315
#   Downloading part 1...   skipped part 1- got bad request
#   Downloading part 2...   skipped part 2- got bad request
#   Downloading part 3...   skipped part 3- got bad request
#   Downloading part 4...   skipped part 4- got bad request
#   Downloading part 5...   skipped part 5- got bad request
#   Downloading part 6...   skipped part 6- got bad request
#   Downloading part 7...   skipped part 7- got bad request
#   Downloading part 8...   skipped part 8- got bad request
#   Downloading part 9...   skipped part 9- got bad request
#   Downloading part 10...   skipped part 10- got bad request
#   Downloading part 11...   skipped part 11- got bad request
# Downloading observation   10479336
#   Downloading part 1...   skipped part 1- got bad request
#   Downloading part 2...   skipped part 2- got bad request
#   Downloading part 3...   skipped part 3- got bad request
#   Downloading part 4...   skipped part 4- got bad request
#   Downloading part 5...   skipped part 5- got bad request
#   Downloading part 6...   skipped part 6- got bad request
#   Downloading part 7...   skipped part 7- got bad request
#   Downloading part 8...   skipped part 8- got bad request
#   Downloading part 9...   skipped part 9- got bad request
#   Downloading part 10...   skipped part 10- got bad request
#   Downloading part 11...   skipped part 11- got bad request
# Downloading observation   10484602
#   File Data/10484602-TIC_292318612_Aab_1.zip already downloaded
#   File Data/10484602-TIC_292318612_Aab_2.zip already downloaded
# Downloading observation   10495390
#   Downloading part 1...   skipped part 1- got bad request
#   Downloading part 2...   skipped part 2- got bad request
#   Downloading part 3...   skipped part 3- got bad request
#   Downloading part 4...   skipped part 4- got bad request
#   Downloading part 5...   skipped part 5- got bad request
# Downloading observation   10506491
#   Downloading part 1...   skipped part 1- got bad request
#   Downloading part 2...   skipped part 2- got bad request
#   Downloading part 3...   skipped part 3- got bad request
#   Downloading part 4...   skipped part 4- got bad request
#   Downloading part 5...   skipped part 5- got bad request
# Downloading observation   10506493
#   File Data/10506493-TIC_307119043_Ab_1.zip already downloaded
#   File Data/10506493-TIC_307119043_Ab_2.zip already downloaded
#   File Data/10506493-TIC_307119043_Ab_3.zip already downloaded
#   File Data/10506493-TIC_307119043_Ab_4.zip already downloaded
#   File Data/10506493-TIC_307119043_Ab_5.zip already downloaded
# Downloading observation   10517885
#   File Data/10517885-TIC_4707_Aa_1.zip already downloaded
#   File Data/10517885-TIC_4707_Aa_2.zip already downloaded
#   File Data/10517885-TIC_4707_Aa_3.zip already downloaded
#   File Data/10517885-TIC_4707_Aa_4.zip already downloaded
#   File Data/10517885-TIC_4707_Aa_5.zip already downloaded
# Downloading observation   10587687
#   File Data/10587687-TIC_292318612_Aab_1.zip already downloaded
#   File Data/10587687-TIC_292318612_Aab_2.zip already downloaded
# Downloading observation   10599724
#   File Data/10599724-TIC_219469945_1.zip already downloaded
#   File Data/10599724-TIC_219469945_2.zip already downloaded
# Downloading observation   10633190
#   Downloading part 1...   skipped part 1- got bad request
#   Downloading part 2...   skipped part 2- got bad request
#   Downloading part 3...   skipped part 3- got bad request
#   Downloading part 4...   skipped part 4- got bad request
#   Downloading part 5...   skipped part 5- got bad request
#   Downloading part 6...   skipped part 6- got bad request
#   Downloading part 7...   skipped part 7- got bad request
# Downloading observation   10710357
#   Downloading part 1...   skipped part 1- got bad request
# Downloading observation   10738609
#   File Data/10738609-TIC_367448265_Bb_1.zip already downloaded
#   File Data/10738609-TIC_367448265_Bb_2.zip already downloaded
#   File Data/10738609-TIC_367448265_Bb_3.zip already downloaded
#   File Data/10738609-TIC_367448265_Bb_4.zip already downloaded
#   File Data/10738609-TIC_367448265_Bb_5.zip already downloaded
#   File Data/10738609-TIC_367448265_Bb_6.zip already downloaded
#   File Data/10738609-TIC_367448265_Bb_7.zip already downloaded
# Downloading observation   10744803
#   File Data/10744803-TIC_367448265_Bb_1.zip already downloaded
#   File Data/10744803-TIC_367448265_Bb_2.zip already downloaded
#   File Data/10744803-TIC_367448265_Bb_3.zip already downloaded
#   File Data/10744803-TIC_367448265_Bb_4.zip already downloaded
#   File Data/10744803-TIC_367448265_Bb_5.zip already downloaded
#   File Data/10744803-TIC_367448265_Bb_6.zip already downloaded
#   File Data/10744803-TIC_367448265_Bb_7.zip already downloaded
# Downloading observation   10764557
#   File Data/10764557-TIC_367448265_A_1.zip already downloaded
#   File Data/10764557-TIC_367448265_A_2.zip already downloaded
#   File Data/10764557-TIC_367448265_A_3.zip already downloaded
#   File Data/10764557-TIC_367448265_A_4.zip already downloaded
# Downloading observation   10819553
#   Downloading part 1...   skipped part 1- got bad request
#   Downloading part 2...   skipped part 2- got bad request
#   Downloading part 3...   skipped part 3- got bad request
#   Downloading part 4...   skipped part 4- got bad request
#   Downloading part 5...   skipped part 5- got bad request
#   Downloading part 6...   skipped part 6- got bad request
#   Downloading part 7...   skipped part 7- got bad request
#   Downloading part 8...   skipped part 8- got bad request
#   Downloading part 9...   skipped part 9- got bad request
#   Downloading part 10...   skipped part 10- got bad request
# Downloading observation   10824118
#   File Data/10824118-TIC_367448265_Bb_maybe_A_1.zip already downloaded
#   File Data/10824118-TIC_367448265_Bb_maybe_A_2.zip already downloaded
#   File Data/10824118-TIC_367448265_Bb_maybe_A_3.zip already downloaded
#   File Data/10824118-TIC_367448265_Bb_maybe_A_4.zip already downloaded
# Downloading observation   10829293
#   File Data/10829293-TIC_367448265_Ba_1.zip already downloaded
#   File Data/10829293-TIC_367448265_Ba_2.zip already downloaded
#   File Data/10829293-TIC_367448265_Ba_3.zip already downloaded
#   File Data/10829293-TIC_367448265_Ba_4.zip already downloaded
# Downloading observation   10845021
#   File Data/10845021-TIC_414969157_Ab_Ba.zip already downloaded
# Downloading observation   10845022
#   File Data/10845022-TIC_414969157_Ab_Ba_1.zip already downloaded
#   File Data/10845022-TIC_414969157_Ab_Ba_2.zip already downloaded
#   File Data/10845022-TIC_414969157_Ab_Ba_3.zip already downloaded
#   File Data/10845022-TIC_414969157_Ab_Ba_4.zip already downloaded
# Downloading observation   10861186
#   File Data/10861186-TIC_307119043_Ab_1.zip already downloaded
#   File Data/10861186-TIC_307119043_Ab_2.zip already downloaded
#   File Data/10861186-TIC_307119043_Ab_3.zip already downloaded
#   File Data/10861186-TIC_307119043_Ab_4.zip already downloaded
#   File Data/10861186-TIC_307119043_Ab_5.zip already downloaded
# Downloading observation   10932571
#   File Data/10932571-TIC_367448265_1.zip already downloaded
#   File Data/10932571-TIC_367448265_2.zip already downloaded
#   File Data/10932571-TIC_367448265_3.zip already downloaded
#   File Data/10932571-TIC_367448265_4.zip already downloaded
#   File Data/10932571-TIC_367448265_5.zip already downloaded
#   File Data/10932571-TIC_367448265_6.zip already downloaded
#   File Data/10932571-TIC_367448265_7.zip already downloaded
#   File Data/10932571-TIC_367448265_8.zip already downloaded
#   File Data/10932571-TIC_367448265_9.zip already downloaded
#   File Data/10932571-TIC_367448265_10.zip already downloaded
#   File Data/10932571-TIC_367448265_11.zip already downloaded
#   File Data/10932571-TIC_367448265_12.zip already downloaded
#   Downloading part 13... got   579.3MB at 66.21Mbps saved to Data/10932571-TIC_367448265_13.zip
# Downloading observation   10932574
#   Downloading part 1...   skipped part 1- got bad request
#   Downloading part 2...   skipped part 2- got bad request
# Downloading observation   11098024
#   Downloading part 1... got  2941.9MB at 60.82Mbps saved to Data/11098024-TIC_63459761_1.zip
#   Downloading part 2... got  2971.6MB at 29.13Mbps saved to Data/11098024-TIC_63459761_2.zip
# Downloading observation   11117322
#   File Data/11117322-TIC_63459761.zip already downloaded
# Downloading observation   11121908
#   File Data/11121908-TIC_63459761.zip already downloaded
# Downloading observation   11130688
#   File Data/11130688-TIC_63459761.zip already downloaded
# Downloading observation   11152433
#   File Data/11152433-TIC_63459761.zip already downloaded
# Downloading observation   11167049
#   File Data/11167049-TIC_63459761.zip already downloaded
# Downloading observation   11182638
#   File Data/11182638-TIC_63459761.zip already downloaded
# Downloading observation   11239406
#   File Data/11239406-TIC_63459761.zip already downloaded
# Downloading observation   11281937
#   File Data/11281937-TIC_63459761.zip already downloaded
# Downloading observation   11281938
#   File Data/11281938-TIC_63459761.zip already downloaded
# Downloading observation   11298603
#   Downloading part 1... got  3224.9MB at 56.58Mbps saved to Data/11298603-TIC_63459761_1.zip
#   Downloading part 2... got  3223.2MB at 23.85Mbps saved to Data/11298603-TIC_63459761_2.zip
#   Downloading part 3... got  3220.0MB at 16.90Mbps saved to Data/11298603-TIC_63459761_3.zip
# Downloading observation   11340723
#   Downloading part 1... got     8.0MB at 32.17Mbps saved to Data/11340723-TIC_63459761_1.zip
#   Downloading part 2... got     8.0MB at 21.44Mbps saved to Data/11340723-TIC_63459761_2.zip
#   Downloading part 3... got     0.0MB at  0.00Mbps saved to Data/11340723-TIC_63459761_3.zip
# Downloading observation   11358293
#   Downloading part 1...   skipped part 1- got bad request
# Downloading observation   11360616
#   File Data/11360616-Dumbbell.zip already downloaded
# Downloading observation   11366635
#   File Data/11366635-eagle_nebula.zip already downloaded
# Downloading observation   11377266
#   File Data/11377266-whirpool_glaxy.zip already downloaded
# Downloading observation   11381425
#   Downloading part 1... got  2045.5MB at 58.44Mbps saved to Data/11381425-tic_1.zip
#   Downloading part 2... got  2074.5MB at 28.61Mbps saved to Data/11381425-tic_2.zip
# Downloading observation   11389811
#   File Data/11389811-TIC_285681367.zip already downloaded
# Downloading observation   11410462
#   File Data/11410462-TIC_219469945.zip already downloaded
# Downloading observation   11458478
#   Downloading part 1... got  1701.9MB at 62.74Mbps saved to Data/11458478-TIC_63459761_1.zip
#   Downloading part 2... got  1697.3MB at 30.11Mbps saved to Data/11458478-TIC_63459761_2.zip
#   Downloading part 3... got  1695.4MB at 20.06Mbps saved to Data/11458478-TIC_63459761_3.zip
# Downloading observation   11466214
#   File Data/11466214-TIC_284814380.zip already downloaded
# Downloading observation   11499670
#   Downloading part 1... got  3191.6MB at 65.30Mbps saved to Data/11499670-TIC_63459761_1.zip
#   Downloading part 2... got  3199.0MB at 31.44Mbps saved to Data/11499670-TIC_63459761_2.zip
# Downloading observation   11593072
#   Downloading part 1... got    25.7MB at 68.54Mbps saved to Data/11593072-tic_344541836.zip
# Downloading observation   11593073
#   Downloading part 1... got    25.8MB at 68.92Mbps saved to Data/11593073-TIC_278465736.zip
# Downloading observation   11593074
#   Downloading part 1...   skipped part 1- got bad request
# Downloading observation   11593075
#   Downloading part 1... got    12.1MB at 48.38Mbps saved to Data/11593075-tic161043618.zip
# Downloading observation   11593076
#   Downloading part 1... got     4.4MB at 34.98Mbps saved to Data/11593076-tic161043618.zip
# Downloading observation   11593786
#   Downloading part 1... got    12.1MB at 48.24Mbps saved to Data/11593786-tic_344541836.zip
# Downloading observation   11594178
#   Downloading part 1... got    12.2MB at 48.83Mbps saved to Data/11594178-tic_278465736.zip
# Downloading observation   11594179
#   Downloading part 1... got    12.4MB at 49.58Mbps saved to Data/11594179-tic_278465736.zip
# Downloading observation   11594180
#   Downloading part 1... got    36.5MB at 58.47Mbps saved to Data/11594180-tic367448265.zip
# Downloading observation   11594183
#   Downloading part 1...
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# File c:\Users\User\anaconda3\envs\Astro\Lib\site-packages\urllib3\response.py:737, in HTTPResponse._error_catcher(self)
#     736 try:
# --> 737     yield
#     739 except SocketTimeout as e:
#     740     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     741     # there is yet no clean way to get at it from this context.
#
# File c:\Users\User\anaconda3\envs\Astro\Lib\site-packages\urllib3\response.py:1187, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1186     break
# -> 1187 chunk = self._handle_chunk(amt)
#    1188 decoded = self._decode(
#    1189     chunk, decode_content=decode_content, flush_decoder=False
#    1190 )
#
# File c:\Users\User\anaconda3\envs\Astro\Lib\site-packages\urllib3\response.py:1138, in HTTPResponse._handle_chunk(self, amt)
#    1137 else:  # amt > self.chunk_left
# -> 1138     returned_chunk = self._fp._safe_read(self.chunk_left)  # type: ignore[union-attr]
#    1139     self._fp._safe_read(2)  # type: ignore[union-attr] # Toss the CRLF at the end of the chunk.
#
# File c:\Users\User\anaconda3\envs\Astro\Lib\http\client.py:642, in HTTPResponse._safe_read(self, amt)
#     641 if len(data) < amt:
# --> 642     raise IncompleteRead(data, amt-len(data))
#     643 return data
#
# IncompleteRead: IncompleteRead(178 bytes read, 7822 more expected)
#
# The above exception was the direct cause of the following exception:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\User\anaconda3\envs\Astro\Lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     815 try:
# --> 816     yield from self.raw.stream(chunk_size, decode_content=True)
#     817 except ProtocolError as e:
#
# File c:\Users\User\anaconda3\envs\Astro\Lib\site-packages\urllib3\response.py:1040, in HTTPResponse.stream(self, amt, decode_content)
#    1039 if self.chunked and self.supports_chunked_reads():
# -> 1040     yield from self.read_chunked(amt, decode_content=decode_content)
#    1041 else:
#
# File c:\Users\User\anaconda3\envs\Astro\Lib\site-packages\urllib3\response.py:1172, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1167     raise BodyNotHttplibCompatible(
#    1168         "Body should be http.client.HTTPResponse like. "
#    1169         "It should have have an fp attribute which returns raw chunks."
#    1170     )
# -> 1172 with self._error_catcher():
#    1173     # Don't bother reading the body of a HEAD request.
#    1174     if self._original_response and is_response_to_head(self._original_response):
#
# File c:\Users\User\anaconda3\envs\Astro\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\User\anaconda3\envs\Astro\Lib\site-packages\urllib3\response.py:764, in HTTPResponse._error_catcher(self)
#     763 except (HTTPException, OSError) as e:
# --> 764     raise ProtocolError(f"Connection broken: {e!r}", e) from e
#     766 # If no exception is thrown, we should avoid cleaning up
#     767 # unnecessarily.
#
# ProtocolError: ('Connection broken: IncompleteRead(178 bytes read, 7822 more expected)', IncompleteRead(178 bytes read, 7822 more expected))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# Cell In[6], line 30
#      28 for part_num in range(1, num_parts + 1):
#      29     try:
# ---> 30         download_file_part(data_directory, obs_id, target, num_parts, part_num)
#      31     except errors.BadRequestError:
#      32         print(f"  skipped part {part_num}- got bad request")
#
# Cell In[6], line 13, in download_file_part(data_directory, obs_id, target, num_parts, part_num)
#      11     return
#      12 print(f"  Downloading part {part_num}...", end=" ")
# ---> 13 _, data = download.fits(**{"obs": obs_id}, total_parts=num_parts, part=part_num)
#      14 filesize = len(data)
#      15 duration = datetime.now() - start
#
# File c:\Users\User\Dropbox\Astro\Other\SkyNet API\skynet\api\v20\methods\download.py:234, in fits(api_key, server, **kwargs)
#     165 def fits(api_key=None, server=None, **kwargs):
#     166     """
#     167     Download image(s) in FITS format
#     168
#    (...)
#     232         ZIP archive contents
#     233     """
# --> 234     return api_call(
#     235         'download/fits', 'get', kwargs, server=server, api_key=api_key)
#
# File c:\Users\User\Dropbox\Astro\Other\SkyNet API\skynet\api\v20\client.py:192, in api_call(resource, method, params, server, api_key)
#     189     kwargs['verify'] = False
#     190     server = BASE_URL[server]
# --> 192 r = requests.request(
#     193     method.upper(), '{}/{}'.format(server, resource), **kwargs)
#     195 if r.status_code != 200:
#     196     # An error occurred
#     197     exc = None
#
# File c:\Users\User\anaconda3\envs\Astro\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\User\anaconda3\envs\Astro\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\User\anaconda3\envs\Astro\Lib\site-packages\requests\sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File c:\Users\User\anaconda3\envs\Astro\Lib\site-packages\requests\models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File c:\Users\User\anaconda3\envs\Astro\Lib\site-packages\requests\models.py:818, in Response.iter_content.<locals>.generate()
#     816     yield from self.raw.stream(chunk_size, decode_content=True)
#     817 except ProtocolError as e:
# --> 818     raise ChunkedEncodingError(e)
#     819 except DecodeError as e:
#     820     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ('Connection broken: IncompleteRead(178 bytes read, 7822 more expected)', IncompleteRead(178 bytes read, 7822 more expected))

# %%
num_images = 1008
num_parts = num_images // 1000 + 1
list(range(1, num_parts+1))
# Out:
# [1, 2]
